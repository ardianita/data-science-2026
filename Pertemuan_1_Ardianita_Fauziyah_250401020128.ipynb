# %% [markdown]
# <a href="https://colab.research.google.com/github/ardianita/data-science-2026/blob/main/Pertemuan_1_Ardianita_Fauziyah_250401020128.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Ardianita Fauziyah
#
# NIM : 250401020128
#
# Kelas : IF403

# %%
# SEL 1 : Output Sederhana
print("Hello, Data Science!")
print("Selamat Datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat Datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2 : Variabel dan Tipe Data
nama      = "Mahasiswa Informatika"
angkatan  = 2024
ipk       = 3.75
aktif     = True

print(f"Nama      : {nama}")
print(f"Angkatan  : {angkatan}")
print(f"IPK       : {ipk}")
print(f"Aktif     : {aktif}")
# Out:
# Nama      : Mahasiswa Informatika
# Angkatan  : 2024
# IPK       : 3.75
# Aktif     : True

# %%
# SEL 3 : List dan Perulangan
tools = ["Phyton", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i,tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Phyton
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
# SEL 4 : Fungsi Phyton
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi} angkatan {angkatan}"

hasil = perkenalan("Budi Santoso","Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Budi Santoso dari Informatika angkatan 2024

# %% [markdown]
# **Kesimpulan** : Di pertemuan ini saya dapat mempelajari tentang bagaimana cara menampilkan output sederhana dan cara membuat variable, list, perulangan (looping), dan fungsi yang digunakan di phyton.
